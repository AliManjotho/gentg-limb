# %% [markdown]
# # GenTG-Limb Quickstart

# %% [markdown]
# Run a minimal inference demo and verify the install.

# %%
# !python --version

# %%
# !pip list | grep torch || echo 'Ensure PyTorch is installed.'

# %%
import numpy as np, torch
print('CUDA available:', torch.cuda.is_available())

# %%
# Create a dummy k2d sequence and run scripts/infer.py once you have checkpoints
# !python scripts/infer.py --config configs/infer/offline_seq.yaml --input data/h36m/sample_seq.npz
