# %% [markdown]
# # Train TGT — Logs & Curves

# %% [markdown]
# Visualize training logs (TensorBoard) or parse stdout logs to plot losses/metrics.

# %%
# Option A: launch TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# Option B: parse custom CSV logs if available
