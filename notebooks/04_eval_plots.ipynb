# %% [markdown]
# # Evaluation Plots

# %% [markdown]
# Plot MPJPE/PCK curves and qualitative frames.

# %%
import numpy as np, matplotlib.pyplot as plt
from pathlib import Path
npz = Path('outputs/infer_result.npz')
if npz.exists():
    xyz = np.load(npz)['xyz']
    print('XYZ:', xyz.shape)
else:
    print('Run inference to create outputs/infer_result.npz')
